# %%
import pandas as pd

# Load the 2 churn prediction datasets
df1 = pd.read_csv("C:/Users/fatma/Downloads/Data Set For Task-20260409T174414Z-3-001/Data Set For Task/Churn Prdiction Data/churn-bigml-20.csv")
print(df1.shape)

df2 = pd.read_csv("C:/Users/fatma/Downloads/Data Set For Task-20260409T174414Z-3-001/Data Set For Task/Churn Prdiction Data/churn-bigml-80.csv")
print(df1.shape)

# Combine
df = pd.concat([df1, df2], ignore_index=True)

# Save new combined file
df.to_csv("C:/Users/fatma/Downloads/combined_churn_dataset.csv", index=False)

print(df.shape)
# Out:
# (667, 20)
# (667, 20)
# (3333, 20)

# %%
import pandas as pd

df = pd.read_csv("combined_churn_dataset.csv")

# Clean column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# Check missing values
print(df.isnull().sum())

# Remove duplicates
df = df.drop_duplicates()

# Convert Yes/No to 1/0
df['international_plan'] = df['international_plan'].map({'Yes':1, 'No':0})
df['voice_mail_plan'] = df['voice_mail_plan'].map({'Yes':1, 'No':0})

# Convert TRUE/FALSE to 1/0
df['churn'] = df['churn'].map({True:1, False:0})

# Final check
print(df.info())
# Out:
# state                     0
# account_length            0
# area_code                 0
# international_plan        0
# voice_mail_plan           0
# number_vmail_messages     0
# total_day_minutes         0
# total_day_calls           0
# total_day_charge          0
# total_eve_minutes         0
# total_eve_calls           0
# total_eve_charge          0
# total_night_minutes       0
# total_night_calls         0
# total_night_charge        0
# total_intl_minutes        0
# total_intl_calls          0
# total_intl_charge         0
# customer_service_calls    0
# churn                     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account_length          3333 non-null   int64
#  2   area_code               3333 non-null   int64
# ...
