# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load combined dataset
df = pd.read_csv("combined_churn_dataset.csv")

# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
print(df.columns) 

# Convert TRUE/FALSE to 1/0 
if df['churn'].dtype == 'object':
    df['churn'] = df['churn'].map({'TRUE':1, 'FALSE':0, 'True':1, 'False':0})
# Out:
# Index(['state', 'account_length', 'area_code', 'international_plan',
#        'voice_mail_plan', 'number_vmail_messages', 'total_day_minutes',
#        'total_day_calls', 'total_day_charge', 'total_eve_minutes',
#        'total_eve_calls', 'total_eve_charge', 'total_night_minutes',
#        'total_night_calls', 'total_night_charge', 'total_intl_minutes',
#        'total_intl_calls', 'total_intl_charge', 'customer_service_calls',
#        'churn'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

X = df[['total_day_minutes']]
y = df['total_day_charge']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("R2:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))


print('A linear regression model was used to predict total day charge based on total day minutes. The model showed a strong linear relationship between the two variables.')
# Out:
# R2: 0.9999999150046418
# MSE: 7.873739475639458e-06
# A linear regression model was used to predict total day charge based on total day minutes. The model showed a strong linear relationship between the two variables.
